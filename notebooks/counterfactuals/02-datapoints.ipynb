# %%
import pandas as pd

df = pd.read_csv("../../datasets/FICO/heloc_dataset_v1.csv")

# %%
from xgboost.sklearn import XGBClassifier

model = XGBClassifier()

# %%
model.load_model("../../models/xgboost.json")

# %%
probabilities = [0.6 + i/50.0 for i in range(10)]
print(probabilities)
# Out:
# [0.6, 0.62, 0.64, 0.6599999999999999, 0.6799999999999999, 0.7, 0.72, 0.74, 0.76, 0.78]

# %%
import utils

series = [utils.get_negative_closest(model, probability) for probability in probabilities]

# %%
df = pd.concat(series, axis=1).T

# %%
len(df.index.unique())
# Out:
# 10

# %%
df
# Out:
#       ExternalRiskEstimate  MSinceOldestTradeOpen  MSinceMostRecentTradeOpen  \
# 1954                    70                    142                          9
# 6014                    61                    113                          3
# 132                     71                    103                         15
# 5369                    79                     66                         19
# 3396                    66                    258                          7
# 3457                    60                    236                          3
# 5727                    61                    264                         11
# 8736                    61                    425                         34
# 7301                    68                    161                          2
# 5157                    65                     49                          9
#
#       AverageMInFile  NumSatisfactoryTrades  NumTrades60Ever2DerogPubRec  \
# ...

# %%
df.to_csv("../../datasets/datapoints.csv", index=False)
