# %% [markdown]
# # ALIBI-proto
# ## Load data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

df = pd.read_csv("../../datasets/FICO/heloc_dataset_v1.csv")

# %%
TARGET = "RiskPerformance"

# %%
from sklearn.model_selection import train_test_split

df[TARGET] = df[TARGET].factorize()[0]

train, test = train_test_split(df, test_size=0.25, random_state=42)

# %%
train_x = train[df.columns[~train.columns.isin([TARGET])]]

# %% [markdown]
# ## XGBoost
#
# ### Load model

# %%
from xgboost.sklearn import XGBClassifier

model = XGBClassifier()

# %%
model.load_model("../../models/xgboost.json")

# %% [markdown]
# ### Standard counterfactuals

# %%
import tensorflow as tf

tf.keras.backend.clear_session()
tf.compat.v1.disable_eager_execution()
tf.compat.v1.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /Users/rui/.virtualenvs/experiments-alibi/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from alibi.explainers import CounterfactualProto

# %%
shape = (1, 23)

# %%
predict_fn = lambda x: model.predict_proba(x)

# %%
def build_cf(pfn):
    _cf = CounterfactualProto(
        pfn,
        shape,
        use_kdtree=True,
        theta=100.0,
        max_iterations=200,
        feature_range=(-20, 1000),
        c_init=2.0,
        c_steps=80,
    )
    return _cf

# %%
cf = build_cf(predict_fn)

# %%
import utils
import pandas as pd

datapoints = pd.read_csv("../../datasets/datapoints.csv")

# %%
cf.fit(train_x.to_numpy())
# Out:
# No encoder specified. Using k-d trees to represent class prototypes.
# CounterfactualProto(meta={
#   'name': 'CounterfactualProto',
#   'type': ['blackbox', 'tensorflow', 'keras'],
#   'explanations': ['local'],
#   'params': {
#               'kappa': 0.0,
#               'beta': 0.1,
#               'feature_range': (-20, 1000),
#               'gamma': 0.0,
#               'theta': 100.0,
#               'cat_vars': None,
#               'ohe': False,
#               'use_kdtree': True,
#               'learning_rate_init': 0.01,
#               'max_iterations': 200,
#               'c_init': 2.0,
#               'c_steps': 80,
#               'eps': (0.001, 0.001),
#               'clip': (-1000.0, 1000.0),
#               'update_num_grad': 1,
#               'write_dir': None,
#               'shape': (1, 23),
#               'is_model': False,
#               'is_ae': False,
#               'is_enc': False,
#               'enc_or_kdtree': True,
#               'is_cat': False,
#               'trustscore_kwargs': None,
#               'd_type': 'abdm',
#               'w': None,
#               'disc_perc': (25, 50, 75),
#               'standardize_cat_vars': False,
#               'smooth': 1.0,
#               'center': True,
#               'update_feature_range': True}
#             ,
#   'version': '0.6.4'}
# )

# %% [markdown]
# ### Store results

# %%
def create_result_df(_explanation, X, model: str):
    N_cf = 1
    schema = utils.get_result_schema()
    v = [[] for i in range(23)]
    o = [[] for i in range(23)]
    goalValue = []
    goalScore = []
    for i in range(N_cf):
        ccf = _explanation['data']['cf']
        values = ccf['X'].tolist()[0]
        goalValue.append(ccf['class'])
        goalScore.append(ccf['proba'].tolist()[0][1])
        for j in range(23):
            v[j].append(values[j])
            o[j].append(X[0][j])

    d = {e[0]: e[1] for e in zip(schema[23:-4], v)}
    od = {e[0]: e[1] for e in zip(schema[:23], o)}
    goal = {"GoalValue": goalValue, "GoalScore": goalScore, "GoalName": ["RiskPerformance"] * N_cf}
    method = ["Alibi-Proto"] * N_cf

    return utils.save_result(original=od, cf=d, score=goal, method=method, model=model)

# %%
counterfactuals = []
for i in range(10):
    print(f"Running counterfactual search #{i}")
    X = datapoints.iloc[i].to_numpy().reshape(1, -1)
    explanation = cf.explain(X)
    result = create_result_df(explanation, X, "XGBoost")
    counterfactuals.append(result)
# Out:
# Running counterfactual search #0
# Running counterfactual search #1
# Running counterfactual search #2
# Running counterfactual search #3
# Running counterfactual search #4
# Running counterfactual search #5
# Running counterfactual search #6
# Running counterfactual search #7
# Running counterfactual search #8
# Running counterfactual search #9

# %%
xgboost_final = pd.concat(counterfactuals)

# %%
xgboost_final
# Out:
#    ExternalRiskEstimate  MSinceOldestTradeOpen  MSinceMostRecentTradeOpen  \
# 0                    70                    142                          9
# 0                    61                    113                          3
# 0                    71                    103                         15
# 0                    79                     66                         19
# 0                    66                    258                          7
# 0                    60                    236                          3
# 0                    61                    264                         11
# 0                    61                    425                         34
# 0                    68                    161                          2
# 0                    65                     49                          9
#
#    AverageMInFile  NumSatisfactoryTrades  NumTrades60Ever2DerogPubRec  \
# 0              47                     16                            0
# 0              29                     32                            0
# 0              94                      6                            1
# 0              35                      5                            0
# 0              94                     17                            2
# 0              83                     41                            1
# 0             110                     12                            4
# 0             103                     13                            4
# 0              58                      1                            0
# 0              23                     11                            0
#
#    NumTrades90Ever2DerogPubRec  PercentTradesNeverDelq  MSinceMostRecentDelq  \
# 0                            0                     100                    -7
# 0                            0                     100                    -7
# 0                            0                      86                    13
# 0                            0                     100                    -7
# 0                            2                      95                    19
# 0                            0                      86                    17
# 0                            3                      69                     4
# 0                            4                      79                    37
# 0                            0                      67                    53
# 0                            0                     100                    -7
#
#    MaxDelq2PublicRecLast12M  ...  CfNetFractionInstallBurden  \
# 0                         7  ...                   61.068050
# 0                         7  ...                   64.437485
# 0                         6  ...                   -8.000000
# 0                         7  ...                   26.100000
# 0                         6  ...                   -8.000000
# 0                         6  ...                   -8.000000
# 0                         2  ...                   -8.000000
# 0                         0  ...                   75.900002
# 0                         6  ...                   96.900002
# 0                         7  ...                   72.099998
#
#    CfNumRevolvingTradesWBalance  CfNumInstallTradesWBalance  \
# 0                      3.871625                    2.000000
# 0                      4.397884                    2.397884
# 0                      2.582994                    0.503786
# 0                      5.900000                    1.100000
# 0                      5.000000                    1.000000
# 0                      5.417006                    1.417006
# 0                      1.000000                   -7.503787
# 0                     13.900000                    8.900000
# 0                      6.900000                    1.000000
# 0                      4.000000                    3.900000
#
#    CfNumBank2NatlTradesWHighUtilization  CfPercentTradesWBalance  GoalValue  \
# 0                              1.000000                55.128376          1
# 0                              1.368181                38.516689          1
# 0                              0.582994                67.000000          1
# 0                              0.000000                90.099998          1
# 0                              1.573093                55.000000          1
# 0                              2.417006                55.605118          1
# 0                              0.000000                33.000000          1
# 0                              8.900000                90.099998          1
# 0                              1.900000               100.000000          1
# 0                             -2.900000                76.900002          1
#
#    GoalScore         GoalName       method    model
# 0   0.525244  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.519465  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.633392  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.523881  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.702892  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.564518  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.652110  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.571569  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.771096  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.539578  RiskPerformance  Alibi-Proto  XGBoost
#
# [10 rows x 51 columns]

# %% [markdown]
# ## MLP

# %% [markdown]
# ## Load model

# %%
from joblib import load

mlp_model = load('../../models/mlp.joblib')

# %%
mlp_predict_fn = lambda x: mlp_model.predict_proba(x)

# %%
mlp_cf = build_cf(mlp_predict_fn)

# %%
mlp_cf.fit(train_x.to_numpy())
# Out:
# No encoder specified. Using k-d trees to represent class prototypes.
# CounterfactualProto(meta={
#   'name': 'CounterfactualProto',
#   'type': ['blackbox', 'tensorflow', 'keras'],
#   'explanations': ['local'],
#   'params': {
#               'kappa': 0.0,
#               'beta': 0.1,
#               'feature_range': (-20, 1000),
#               'gamma': 0.0,
#               'theta': 100.0,
#               'cat_vars': None,
#               'ohe': False,
#               'use_kdtree': True,
#               'learning_rate_init': 0.01,
#               'max_iterations': 200,
#               'c_init': 2.0,
#               'c_steps': 80,
#               'eps': (0.001, 0.001),
#               'clip': (-1000.0, 1000.0),
#               'update_num_grad': 1,
#               'write_dir': None,
#               'shape': (1, 23),
#               'is_model': False,
#               'is_ae': False,
#               'is_enc': False,
#               'enc_or_kdtree': True,
#               'is_cat': False,
#               'trustscore_kwargs': None,
#               'd_type': 'abdm',
#               'w': None,
#               'disc_perc': (25, 50, 75),
#               'standardize_cat_vars': False,
#               'smooth': 1.0,
#               'center': True,
#               'update_feature_range': True}
#             ,
#   'version': '0.6.4'}
# )

# %%
counterfactuals = []
for i in range(10):
    print(f"Running counterfactual search #{i}")
    X = datapoints.iloc[i].to_numpy().reshape(1, -1)
    explanation = mlp_cf.explain(X)
    result = create_result_df(explanation, X, "MLP")
    counterfactuals.append(result)
# Out:
# Running counterfactual search #0
# Running counterfactual search #1
# Running counterfactual search #2
# Running counterfactual search #3
# Running counterfactual search #4
# Running counterfactual search #5
# Running counterfactual search #6
# Running counterfactual search #7
# Running counterfactual search #8
# Running counterfactual search #9

# %%
mlp_final = pd.concat(counterfactuals)

# %%
final_df = pd.concat([xgboost_final, mlp_final])

# %%
final_df
# Out:
#    ExternalRiskEstimate  MSinceOldestTradeOpen  MSinceMostRecentTradeOpen  \
# 0                    70                    142                          9
# 0                    61                    113                          3
# 0                    71                    103                         15
# 0                    79                     66                         19
# 0                    66                    258                          7
# 0                    60                    236                          3
# 0                    61                    264                         11
# 0                    61                    425                         34
# 0                    68                    161                          2
# 0                    65                     49                          9
# 0                    70                    142                          9
# 0                    61                    113                          3
# 0                    71                    103                         15
# 0                    79                     66                         19
# 0                    66                    258                          7
# 0                    60                    236                          3
# 0                    61                    264                         11
# 0                    61                    425                         34
# 0                    68                    161                          2
# 0                    65                     49                          9
#
#    AverageMInFile  NumSatisfactoryTrades  NumTrades60Ever2DerogPubRec  \
# 0              47                     16                            0
# 0              29                     32                            0
# 0              94                      6                            1
# 0              35                      5                            0
# 0              94                     17                            2
# 0              83                     41                            1
# 0             110                     12                            4
# 0             103                     13                            4
# 0              58                      1                            0
# 0              23                     11                            0
# 0              47                     16                            0
# 0              29                     32                            0
# 0              94                      6                            1
# 0              35                      5                            0
# 0              94                     17                            2
# 0              83                     41                            1
# 0             110                     12                            4
# 0             103                     13                            4
# 0              58                      1                            0
# 0              23                     11                            0
#
#    NumTrades90Ever2DerogPubRec  PercentTradesNeverDelq  MSinceMostRecentDelq  \
# 0                            0                     100                    -7
# 0                            0                     100                    -7
# 0                            0                      86                    13
# 0                            0                     100                    -7
# 0                            2                      95                    19
# 0                            0                      86                    17
# 0                            3                      69                     4
# 0                            4                      79                    37
# 0                            0                      67                    53
# 0                            0                     100                    -7
# 0                            0                     100                    -7
# 0                            0                     100                    -7
# 0                            0                      86                    13
# 0                            0                     100                    -7
# 0                            2                      95                    19
# 0                            0                      86                    17
# 0                            3                      69                     4
# 0                            4                      79                    37
# 0                            0                      67                    53
# 0                            0                     100                    -7
#
#    MaxDelq2PublicRecLast12M  ...  CfNetFractionInstallBurden  \
# 0                         7  ...                   61.068050
# 0                         7  ...                   64.437485
# 0                         6  ...                   -8.000000
# 0                         7  ...                   26.100000
# 0                         6  ...                   -8.000000
# 0                         6  ...                   -8.000000
# 0                         2  ...                   -8.000000
# 0                         0  ...                   75.900002
# 0                         6  ...                   96.900002
# 0                         7  ...                   72.099998
# 0                         7  ...                   72.438942
# 0                         7  ...                   72.000000
# 0                         6  ...                   -8.000000
# 0                         7  ...                   36.000000
# 0                         6  ...                   -8.000000
# 0                         6  ...                   -8.000000
# 0                         2  ...                   -8.000000
# 0                         0  ...                   56.099998
# 0                         6  ...                   95.584206
# 0                         7  ...                   70.120049
#
#    CfNumRevolvingTradesWBalance  CfNumInstallTradesWBalance  \
# 0                      3.871625                    2.000000
# 0                      4.397884                    2.397884
# 0                      2.582994                    0.503786
# 0                      5.900000                    1.100000
# 0                      5.000000                    1.000000
# 0                      5.417006                    1.417006
# 0                      1.000000                   -7.503787
# 0                     13.900000                    8.900000
# 0                      6.900000                    1.000000
# 0                      4.000000                    3.900000
# 0                      2.981721                    2.000000
# 0                      8.000000                    6.000000
# 0                      3.573093                    0.503786
# 0                      2.000000                    3.000000
# 0                      6.573093                    1.000000
# 0                      5.417006                    1.417006
# 0                      1.000000                   -7.781518
# 0                      5.900000                   10.900000
# 0                      5.584043                    1.000000
# 0                      4.000000                    7.869925
#
#    CfNumBank2NatlTradesWHighUtilization  CfPercentTradesWBalance  GoalValue  \
# 0                              1.000000                55.128376          1
# 0                              1.368181                38.516689          1
# 0                              0.582994                67.000000          1
# 0                              0.000000                90.099998          1
# 0                              1.573093                55.000000          1
# 0                              2.417006                55.605118          1
# 0                              0.000000                33.000000          1
# 0                              8.900000                90.099998          1
# 0                              1.900000               100.000000          1
# 0                             -2.900000                76.900002          1
# 0                              1.000000                51.918941          0
# 0                              2.000000                73.775055          1
# 0                              0.582994                56.516010          1
# 0                              1.900000                90.099998          1
# 0                              0.000000                53.426903          1
# 0                              2.417006                55.605118          1
# 0                              0.000000                33.000000          1
# 0                              2.900000                90.099998          1
# 0                              1.474769               100.000000          1
# 0                             -2.869925                76.950401          1
#
#    GoalScore         GoalName       method    model
# 0   0.525244  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.519465  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.633392  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.523881  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.702892  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.564518  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.652110  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.571569  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.771096  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.539578  RiskPerformance  Alibi-Proto  XGBoost
# 0   0.407637  RiskPerformance  Alibi-Proto      MLP
# 0   0.597789  RiskPerformance  Alibi-Proto      MLP
# 0   0.538231  RiskPerformance  Alibi-Proto      MLP
# 0   0.534207  RiskPerformance  Alibi-Proto      MLP
# 0   0.662716  RiskPerformance  Alibi-Proto      MLP
# 0   0.576314  RiskPerformance  Alibi-Proto      MLP
# 0   0.500339  RiskPerformance  Alibi-Proto      MLP
# 0   0.520764  RiskPerformance  Alibi-Proto      MLP
# 0   0.502440  RiskPerformance  Alibi-Proto      MLP
# 0   0.626476  RiskPerformance  Alibi-Proto      MLP
#
# [20 rows x 51 columns]

# %%
final_df.to_csv("../../results/cf-alibi-proto.csv")
